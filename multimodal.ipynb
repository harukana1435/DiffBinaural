# %%
# !pip install torch transformers accelerate soundfile pillow scipy torchvision backoff
# !pip install flash-attn --no-build-isolation
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl (766.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.7/766.7 MB 4.0 MB/s eta 0:00:0000:0100:01
# Collecting transformers
#   Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 80.1 MB/s eta 0:00:0000:0100:01
# Collecting accelerate
#   Downloading accelerate-1.4.0-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.1/342.1 KB 61.3 MB/s eta 0:00:00
# Collecting soundfile
#   Using cached soundfile-0.13.1-py2.py3-none-manylinux_2_28_x86_64.whl (1.3 MB)
# Collecting pillow
#   Downloading pillow-11.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 87.9 MB/s eta 0:00:00ta 0:00:01
# Collecting scipy
#   Downloading scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 50.6 MB/s eta 0:00:0000:0100:01
# Collecting torchvision
#   Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 92.0 MB/s eta 0:00:00:00:0100:01
# Collecting backoff
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting networkx
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 94.1 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.6.1.9
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 22.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.21.5
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 16.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12==12.3.1.170
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 13.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparselt-cu12==0.6.2
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 18.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.5.147
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 37.8 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.4.127
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 29.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.4.5.8
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 9.1 MB/s eta 0:00:0000:0100:01
# Collecting sympy==1.13.1
#   Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 79.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.2.1.3
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 14.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch) (3.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 63.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.4.127
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 KB 56.5 MB/s eta 0:00:00
# Collecting triton==3.2.0
#   Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 MB 11.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch) (3.0.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/h-okano/.local/lib/python3.10/site-packages (from torch) (4.12.2)
# Collecting nvidia-nvjitlink-cu12==12.4.127
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 61.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-cupti-cu12==12.4.127
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.8 MB/s eta 0:00:0000:0100:01
# Collecting fsspec
#   Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 KB 50.2 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==9.1.0.70
#   Using cached nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
# Collecting mpmath<1.4,>=1.1.0
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Collecting regex!=2019.12.17
#   Downloading regex-2024.11.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.7/781.7 KB 70.9 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.4.1)
# Collecting numpy>=1.17
#   Downloading numpy-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 60.0 MB/s eta 0:00:0000:0100:01
# Collecting safetensors>=0.4.1
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 KB 49.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /home/h-okano/.local/lib/python3.10/site-packages (from transformers) (24.2)
# Collecting huggingface-hub<1.0,>=0.26.0
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 KB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.25.1)
# Collecting tokenizers<0.22,>=0.21
#   Downloading tokenizers-0.21.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 69.3 MB/s eta 0:00:00a 0:00:01
# Collecting tqdm>=4.27
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from accelerate) (5.9.0)
# Collecting cffi>=1.0
#   Downloading cffi-1.17.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 446.2/446.2 KB 63.6 MB/s eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-2.22-py3-none-any.whl (117 kB)
# Installing collected packages: triton, nvidia-cusparselt-cu12, mpmath, tqdm, sympy, safetensors, regex, pycparser, pillow, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, fsspec, backoff, scipy, nvidia-cusparse-cu12, nvidia-cudnn-cu12, huggingface-hub, cffi, tokenizers, soundfile, nvidia-cusolver-cu12, transformers, torch, torchvision, accelerate
# Successfully installed accelerate-1.4.0 backoff-2.2.1 cffi-1.17.1 fsspec-2025.3.0 huggingface-hub-0.29.3 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.3 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 pillow-11.1.0 pycparser-2.22 regex-2024.11.6 safetensors-0.5.3 scipy-1.15.2 soundfile-0.13.1 sympy-1.13.1 tokenizers-0.21.0 torch-2.6.0 torchvision-0.21.0 tqdm-4.67.1 transformers-4.49.0 triton-3.2.0
# Defaulting to user installation because normal site-packages is not writeable
# Collecting flash-attn
#   Downloading flash_attn-2.7.4.post1.tar.gz (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 36.6 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [21 lines of output]
#
#
#       torch.__version__  = 2.6.0+cu124
#
#
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-1o2265ej/flash-attn_252b333b59b540b386b1177513cf812d/setup.py", line 171, in <module>
#           _, bare_metal_version = get_cuda_bare_metal_version(CUDA_HOME)
#         File "/tmp/pip-install-1o2265ej/flash-attn_252b333b59b540b386b1177513cf812d/setup.py", line 89, in get_cuda_bare_metal_version
#           raw_output = subprocess.check_output([cuda_dir + "/bin/nvcc", "-V"], universal_newlines=True)
#         File "/usr/lib/python3.10/subprocess.py", line 421, in check_output
#           return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#         File "/usr/lib/python3.10/subprocess.py", line 503, in run
#           with Popen(*popenargs, **kwargs) as process:
#         File "/usr/lib/python3.10/subprocess.py", line 971, in __init__
#           self._execute_child(args, executable, preexec_fn, close_fds,
#         File "/usr/lib/python3.10/subprocess.py", line 1863, in _execute_child
#           raise child_exception_type(errno_num, err_msg, err_filename)
#       FileNotFoundError: [Errno 2] No such file or directory: '/opt/cuda/10.1/bin/nvcc'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install peft
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting peft
#   Downloading peft-0.14.0-py3-none-any.whl (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 KB 9.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (24.2)
# Requirement already satisfied: torch>=1.13.0 in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (2.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (2.2.3)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from peft) (5.4.1)
# Requirement already satisfied: psutil in /usr/lib/python3/dist-packages (from peft) (5.9.0)
# Requirement already satisfied: tqdm in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (1.4.0)
# Requirement already satisfied: huggingface-hub>=0.25.0 in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (0.29.3)
# Requirement already satisfied: transformers in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (4.49.0)
# Requirement already satisfied: safetensors in /home/h-okano/.local/lib/python3.10/site-packages (from peft) (0.5.3)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from huggingface-hub>=0.25.0->peft) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/h-okano/.local/lib/python3.10/site-packages (from huggingface-hub>=0.25.0->peft) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/h-okano/.local/lib/python3.10/site-packages (from huggingface-hub>=0.25.0->peft) (4.12.2)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from huggingface-hub>=0.25.0->peft) (2.25.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.3.1.170)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: networkx in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (10.3.5.147)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (0.6.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (3.2.0)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.2.1.3)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (9.1.0.70)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (11.6.1.9)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.5.8)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (2.21.5)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/h-okano/.local/lib/python3.10/site-packages (from torch>=1.13.0->peft) (12.4.127)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/h-okano/.local/lib/python3.10/site-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/h-okano/.local/lib/python3.10/site-packages (from transformers->peft) (0.21.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/h-okano/.local/lib/python3.10/site-packages (from transformers->peft) (2024.11.6)
# Installing collected packages: peft
# Successfully installed peft-0.14.0

# %%
import torch
from transformers import AutoProcessor, AutoModelForCausalLM, GenerationConfig
import os

model_name = "microsoft/Phi-4-multimodal-instruct"

processor = AutoProcessor.from_pretrained(model_name, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    model_name, 
    device_map="cuda" if torch.cuda.is_available() else "cpu",  # GPU が使える場合は CUDA
    torch_dtype=torch.float16,  # メモリ節約
    trust_remote_code=True
)

generation_config = GenerationConfig.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 10
#       7 model_name = "microsoft/Phi-4-multimodal-instruct"
#       9 processor = AutoProcessor.from_pretrained(model_name, trust_remote_code=True)
# ---> 10 model = AutoModelForCausalLM.from_pretrained(
#      11     model_name,
#      12     device_map="cuda" if torch.cuda.is_available() else "cpu",  # GPU が使える場合は CUDA
#      13     torch_dtype=torch.float16,  # メモリ節約
#      14     trust_remote_code=True
#      15 )
#      17 generation_config = GenerationConfig.from_pretrained(model_name)
#
# File ~/.local/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:559, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     557     cls.register(config.__class__, model_class, exist_ok=True)
#     558     model_class = add_generation_mixin_to_remote_model(model_class)
# --> 559     return model_class.from_pretrained(
#     560         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     561     )
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:262, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     260 old_dtype = torch.get_default_dtype()
#     261 try:
# --> 262     return func(*args, **kwargs)
#     263 finally:
#     264     torch.set_default_dtype(old_dtype)
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:4179, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4177 config = copy.deepcopy(config)  # We do not want to modify the config inplace in from_pretrained.
#    4178 if not getattr(config, "_attn_implementation_autoset", False):
# -> 4179     config = cls._autoset_attn_implementation(
#    4180         config, use_flash_attention_2=use_flash_attention_2, torch_dtype=torch_dtype, device_map=device_map
#    4181     )
#    4183 with ContextManagers(init_contexts):
#    4184     # Let's make sure we don't run the init function of buffer modules
#    4185     model = cls(config, *model_args, **model_kwargs)
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:1575, in PreTrainedModel._autoset_attn_implementation(cls, config, use_flash_attention_2, torch_dtype, device_map, check_device_map)
#    1572     config._attn_implementation = "flash_attention_2"
#    1574 if config._attn_implementation == "flash_attention_2":
# -> 1575     cls._check_and_enable_flash_attn_2(
#    1576         config,
#    1577         torch_dtype=torch_dtype,
#    1578         device_map=device_map,
#    1579         hard_check_only=False,
#    1580         check_device_map=check_device_map,
#    1581     )
#    1582 elif requested_attn_implementation == "flex_attention":
#    1583     config = cls._check_and_enable_flex_attn(config, hard_check_only=True)
#
# File ~/.local/lib/python3.10/site-packages/transformers/modeling_utils.py:1710, in PreTrainedModel._check_and_enable_flash_attn_2(cls, config, torch_dtype, device_map, check_device_map, hard_check_only)
#    1707 install_message = "Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2."
#    1709 if importlib.util.find_spec("flash_attn") is None:
# -> 1710     raise ImportError(f"{preface} the package flash_attn seems to be not installed. {install_message}")
#    1712 flash_attention_version = version.parse(importlib.metadata.version("flash_attn"))
#    1713 if torch.version.cuda:
#
# ImportError: FlashAttention2 has been toggled on, but it cannot be used due to the following error: the package flash_attn seems to be not installed. Please refer to the documentation of https://huggingface.co/docs/transformers/perf_infer_gpu_one#flashattention-2 to install Flash Attention 2.
